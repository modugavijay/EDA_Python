# %%
#Play Store app Review Analysis

# %%
#Project Summary

# %%
# Finding the relation between Rating with different variables was found

# %%
#GitHub Link

# %%
https://github.com/modugavijay

# %%
#Problem Statement
find the relatin between rating and other parameters

# %%
#Define Your Bussiness objective
Understand how the rating varies with respect to remaining variables

# %%
#1.Know Your Data
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#Dataset Loading
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-8a86e0a9-76fc-44d9-b581-52fdaf7a0520" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8a86e0a9-76fc-44d9-b581-52fdaf7a0520">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_csv('Play_Store_Data.csv')
print(df)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#Dataset First View

# %%
df.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# ...

# %%
from google.colab import files
uploaded1=files.upload()
# Out:
#      <input type="file" id="files-f1f07635-550b-4323-8fe3-ea556e7248b7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f1f07635-550b-4323-8fe3-ea556e7248b7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df1 = pd.read_csv('User_Reviews.csv')
print(df1)
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %%
df1.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
df1.shape
# Out:
# (64295, 5)

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df1.info
# Out:
# <bound method DataFrame.info of                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %%
#number of duplicate values

# %%
df.duplicated().sum()
# Out:
# 483

# %%
#Missing Vaues

# %%
df.isnull()
# Out:
#          App  Category  Rating  Reviews   Size  Installs   Type  Price  \
# 0      False     False   False    False  False     False  False  False
# 1      False     False   False    False  False     False  False  False
# 2      False     False   False    False  False     False  False  False
# 3      False     False   False    False  False     False  False  False
# 4      False     False   False    False  False     False  False  False
# ...      ...       ...     ...      ...    ...       ...    ...    ...
# 10836  False     False   False    False  False     False  False  False
# 10837  False     False   False    False  False     False  False  False
# 10838  False     False    True    False  False     False  False  False
# 10839  False     False   False    False  False     False  False  False
# 10840  False     False   False    False  False     False  False  False
#
#        Content Rating  Genres  Last Updated  Current Ver  Android Ver
# ...

# %%
#Columns wise missing value count

# %%
df.isnull().count()
# Out:
# App               10841
# Category          10841
# Rating            10841
# Reviews           10841
# Size              10841
# Installs          10841
# Type              10841
# Price             10841
# Content Rating    10841
# Genres            10841
# Last Updated      10841
# Current Ver       10841
# Android Ver       10841
# dtype: int64

# %%
# What did you know about the dataset?


# Answer: I knew how many rows and columns my data set has and missing values and duplicates as well

# %%
list(df.columns)
# Out:
# ['App',
#  'Category',
#  'Rating',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
# 3 Data wrangling
a= max(df['Rating'])
print(a)
a1=df[df['Rating']<=3]
a2=df[df['Rating']>3]
a3=df[df['Rating']==3]
print(a1)
# Out:
# 19.0
#                                                   App         Category  \
# 477                                        Calculator           DATING
# 514                                FarmersOnly Dating           DATING
# 518                     Just She - Top Lesbian Dating           DATING
# 520    EliteSingles – Dating for Single Professionals           DATING
# 527                            Sugar Daddy Dating App           DATING
# ...                                               ...              ...
# 10665                     SB · FN 1870 Mobile Banking          FINANCE
# 10677                                 Pint - FN Theme  PERSONALIZATION
# 10715                              FarmersOnly Dating           DATING
# 10757                    Fisher-Price® Smart Connect™            TOOLS
# 10766                          FreedomPop Diagnostics            TOOLS
#
#        Rating Reviews  Size  Installs  Type   Price Content Rating  \
# ...

# %%
print(a2)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
print(a3)
# Out:
#                                                     App       Category  \
# 514                                  FarmersOnly Dating         DATING
# 546                                          The League         DATING
# 619                      Random Chat App with Strangers         DATING
# 645                             UK Girls Mobile Numbers         DATING
# 915    Acorn TV: World-class TV from Britain and Beyond  ENTERTAINMENT
# ...                                                 ...            ...
# 10151                                           EZ View       BUSINESS
# 10325                                         FE Mobile       BUSINESS
# 10341                                            FE CPS        FINANCE
# 10476                             Lennox iComfort Wi-Fi      LIFESTYLE
# 10715                                FarmersOnly Dating         DATING
#
#        Rating Reviews  Size  Installs  Type Price Content Rating  \
# ...

# %%
a4=pd.concat([a1,a2,a3])

# %%
print(a4)
# Out:
#                                                   App   Category  Rating  \
# 477                                        Calculator     DATING     2.6
# 514                                FarmersOnly Dating     DATING     3.0
# 518                     Just She - Top Lesbian Dating     DATING     1.9
# 520    EliteSingles – Dating for Single Professionals     DATING     2.5
# 527                            Sugar Daddy Dating App     DATING     2.5
# ...                                               ...        ...     ...
# 10151                                         EZ View   BUSINESS     3.0
# 10325                                       FE Mobile   BUSINESS     3.0
# 10341                                          FE CPS    FINANCE     3.0
# 10476                           Lennox iComfort Wi-Fi  LIFESTYLE     3.0
# 10715                              FarmersOnly Dating     DATING     3.0
#
#       Reviews  Size  Installs  Type   Price Content Rating     Genres  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (10841, 13)

# %%
a1.shape, a2.shape , a3.shape
# Out:
# ((370, 13), (8997, 13), (83, 13))

# %%
sample_df=pd.concat([a1,a2],axis=1)
sample_df.tail()
# Out:
#        App Category  Rating Reviews Size Installs Type Price  Content Rating  \
# 10834  NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN             NaN
# 10836  NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN             NaN
# 10837  NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN             NaN
# 10839  NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN             NaN
# 10840  NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN             NaN
#
#       Genres  ... Reviews                Size     Installs  Type Price  \
# 10834    NaN  ...       7                2.6M         500+  Free     0
# 10836    NaN  ...      38                 53M       5,000+  Free     0
# 10837    NaN  ...       4                3.6M         100+  Free     0
# 10839    NaN  ...     114  Varies with device       1,000+  Free     0
# 10840    NaN  ...  398307                 19M  10,000,000+  Free     0
#
# ...

# %%
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9367 entries, 477 to 10840
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             370 non-null    object
#  1   Category        370 non-null    object
#  2   Rating          370 non-null    float64
#  3   Reviews         370 non-null    object
#  4   Size            370 non-null    object
#  5   Installs        370 non-null    object
#  6   Type            370 non-null    object
#  7   Price           370 non-null    object
#  8   Content Rating  370 non-null    object
#  9   Genres          370 non-null    object
#  10  Last Updated    370 non-null    object
#  11  Current Ver     370 non-null    object
#  12  Android Ver     370 non-null    object
#  13  App             8997 non-null   object
#  14  Category        8997 non-null   object
#  15  Rating          8997 non-null   float64
#  16  Reviews         8997 non-null   object
# ...

# %%
sample_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'App', 'Category', 'Rating', 'Reviews', 'Size',
#        'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated',
#        'Current Ver', 'Android Ver'],
#       dtype='object')

# %%
a1.shape,a2.shape
# Out:
# ((370, 13), (8997, 13))

# %%
merge_df1=pd.merge(a1,a2,how='inner',left_on='Current Ver' ,right_on='Current Ver')
print(merge_df)
# Out:
#                               App_x Category_x  Rating_x Reviews_x Size_x  \
# 0                        Calculator     DATING       2.6        57   6.2M
# 1                        Calculator     DATING       2.6        57   6.2M
# 2                        Calculator     DATING       2.6        57   6.2M
# 3                        Calculator     DATING       2.6        57   6.2M
# 4                        Calculator     DATING       2.6        57   6.2M
# ...                             ...        ...       ...       ...    ...
# 50347  Fisher-Price® Smart Connect™      TOOLS       2.7       422    72M
# 50348  Fisher-Price® Smart Connect™      TOOLS       2.7       422    72M
# 50349  Fisher-Price® Smart Connect™      TOOLS       2.7       422    72M
# 50350  Fisher-Price® Smart Connect™      TOOLS       2.7       422    72M
# 50351  Fisher-Price® Smart Connect™      TOOLS       2.7       422    72M
#
#       Installs_x Type_x Price_x Content Rating_x Genres_x  ... Rating_y  \
# ...

# %%
merge_df2=pd.merge(a1,a2,how='left' ,left_on='Current Ver' ,right_on='Current Ver')
print(merge_df2)
# Out:
#                               App_x Category_x  Rating_x Reviews_x Size_x  \
# 0                        Calculator     DATING       2.6        57   6.2M
# 1                        Calculator     DATING       2.6        57   6.2M
# 2                        Calculator     DATING       2.6        57   6.2M
# 3                        Calculator     DATING       2.6        57   6.2M
# 4                        Calculator     DATING       2.6        57   6.2M
# ...                             ...        ...       ...       ...    ...
# 50433  Fisher-Price® Smart Connect™      TOOLS       2.7       422    72M
# 50434  Fisher-Price® Smart Connect™      TOOLS       2.7       422    72M
# 50435  Fisher-Price® Smart Connect™      TOOLS       2.7       422    72M
# 50436  Fisher-Price® Smart Connect™      TOOLS       2.7       422    72M
# 50437        FreedomPop Diagnostics      TOOLS       2.9       452   7.0M
#
#       Installs_x Type_x Price_x Content Rating_x Genres_x  ... Rating_y  \
# ...

# %%
merge_df3=pd.merge(a1,a2,how='right',left_on='Current Ver',right_on='Current Ver')
print(merge_df3)
# Out:
#                            App_x          Category_x  Rating_x Reviews_x  \
# 0                    MouseMingle              DATING       2.7         3
# 1                    MouseMingle              DATING       2.7         3
# 2                       Rugby AU              SPORTS       2.7        17
# 3                    Axe Spinner              FAMILY       3.0         2
# 4               Disc Label Print               TOOLS       3.0       262
# ...                          ...                 ...       ...       ...
# 55135          Svenska Dagbladet  NEWS_AND_MAGAZINES       2.6       820
# 55136                  DW Mobile            BUSINESS       2.7        33
# 55137                  edp re:dy               TOOLS       3.0       172
# 55138                Egg for Pou              FAMILY       3.0     59096
# 55139  Emerge EV App (eBike App)           LIFESTYLE       3.0        26
#
#                    Size_x  Installs_x Type_x Price_x Content Rating_x  \
# ...

# %%
pd.merge(a1[['Price','Rating']],a2, on='Price', how='outer')
# Out:
#             Price  Rating_x                                      App  \
# 0          $6.99        2.6           Call of Duty:Black Ops Zombies
# 1          $6.99        2.6                                Minecraft
# 2          $6.99        2.6                   Journal Club: Medicine
# 3          $6.99        2.6                   Journal Club: Medicine
# 4          $6.99        2.6                                Minecraft
# ...           ...       ...                                      ...
# 2850823    $2.90        NaN                       WiFi Tether Router
# 2850824    $1.97        NaN             Trazado de tuberia El Tubero
# 2850825    $2.56        NaN                               YouCamp EU
# 2850826  Everyone       NaN  Life Made WI-Fi Touchscreen Photo Frame
# 2850827    $1.20        NaN                             sugar, sugar
#
#                  Category  Rating_y  Reviews                Size     Installs  \
# ...

# %%
from datetime import datetime
from datetime import date

# %%
df['new_Rating']= df.apply(lambda x : datetime.strptime(x['App'],'%m/%d/%y'),axis=1)

# %%
def convert_to_year(datevalue):
  return datevalue.year

# %%
#   I learned how to concatenate the two daata frames i fund this is a good insight for me,and removing duplicates and null values.

# %%
1. Why did you pick the specific Chart?
Because now a days everyone uses mobile apps, so doing some analysis will be great.

# %%
2.What is/are the insight(s) found from the chart?
Removing duplicates and null values

# %%
3. Will the gained insights help creating a positive business impact?
Are there any insights that lead to negative growth? Justify with specific reason.

yes the gained insights will help the bussiness.

# %%
#@title Default title text
Data Visualisation

# %%
# Reeviewers giving rating

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Reviews'],df['Rating'],c='red')
plt.title('Reviewers giving rating')
plt.xlabel('Reviews')
plt.ylabel('Rating')
plt.show()

# %%
plt.scatter(df['Size'],df['Installs'],c='green')
plt.title('How the installs happened')
plt.xlabel('Size')
plt.ylabel('Installs')
# Out:
# Text(0, 0.5, 'Installs')

# %%
plt.hist(df['Size'],color='green',edgecolor='white',bins=5)
plt.xlabel('Size')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
plt.hist(df['Rating'],color='green',edgecolor='white',bins=5)
# Out:
# (array([7.449e+03, 1.917e+03, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([ 1. ,  4.6,  8.2, 11.8, 15.4, 19. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(df['Reviews'],color='green',edgecolor='white',bins=5)
# Out:
# (array([4420., 2081., 1583., 1515., 1242.]),
#  array([   0. , 1200.2, 2400.4, 3600.6, 4800.8, 6001. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(df['Installs'],color='green',edgecolor='white',bins=5)
# Out:
# (array([3803., 3787., 1446., 1640.,  165.]),
#  array([ 0. ,  4.2,  8.4, 12.6, 16.8, 21. ]),
#  <BarContainer object of 5 artists>)

# %%
import seaborn as sns
sns.set(style="darkgrid")
sns.regplot(x=df['Reviews'],y=df['Rating'])
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-6-7a38298c687f> in <cell line: 3>()
#       1 import seaborn as sns
#       2 sns.set(style='darkgrid')
# ----> 3 sns.regplot(x=df['Reviews'],y=df['Rating'])
#
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     757     scatter_kws["marker"] = marker
#     758     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 759     plotter.plot(ax, scatter_kws, line_kws)
#     760     return ax
#     761
#
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py in plot(self, ax, scatter_kws, line_kws)
#     366
#     367         if self.fit_reg:
# ...

# %%
sns.countplot(y="Reviews",data=df)
# Out:
# <Axes: xlabel='count', ylabel='Reviews'>

# %%
sns.boxplot(y=df["Rating"])
# Out:
# <Axes: ylabel='Rating'>
